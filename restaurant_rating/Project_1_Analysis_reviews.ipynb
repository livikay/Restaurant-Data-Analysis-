# %%
#set up dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading csv for precovid ohio
precovid_ohio = "precovid_ohio2019.csv"
precovid_ohio_df = pd.read_csv(precovid_ohio)
precovid_ohio_df
# Out:
#                  business_id         name state_      city  stars  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# ...                      ...          ...    ...       ...    ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
#
#       review_count  is_open  \
# 0               16        0
# 1               16        0
# 2               16        0
# 3               16        0
# ...

# %%
#getting columns needed for dataframe
reduced_preohio =precovid_ohio_df[["business_id", "name", "state_", "city", "stars", "review_count", "customer_stars", "date_"]]
reduced_preohio
# Out:
#                  business_id         name state_      city  stars  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# ...                      ...          ...    ...       ...    ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
#
#       review_count  customer_stars            date_
# 0               16               5  1/20/2019 17:28
# 1               16               5   2/17/2019 2:45
# ...

# %%
#getting rid of any null values
red_preohio = reduced_preohio[reduced_preohio["business_id"] != "#NAME?"]
red_preohio
# Out:
#                  business_id         name state_      city  stars  \
# 0     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 1     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 2     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 3     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# 4     KPZHg7BGkyhLAZmUTIJnMw  & Juice Co.     OH  Columbus    4.5
# ...                      ...          ...    ...       ...    ...
# 5348  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5349  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5350  FyGavoQ1DdC3ZsjKAfxezA        Zoup!     OH  Columbus    4.0
# 5351  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
# 5352  IJVqt4PE0QKaqJ2VfBYBZg        Zoup!     OH  Columbus    3.0
#
#       review_count  customer_stars            date_
# 0               16               5  1/20/2019 17:28
# 1               16               5   2/17/2019 2:45
# ...

# %%
#reading postcovid csv
postcovid_ohio = "postcovid_ohio2020.csv"
postcovid_ohio_df = pd.read_csv(postcovid_ohio)
postcovid_ohio_df
# Out:
#                   business_id              name state_         city  stars  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# ...                       ...               ...    ...          ...    ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
#
#        review_count  is_open  \
# 0               318        1
# ...

# %%
#getting columns needed for dataframe
reduced_postohio =postcovid_ohio_df[["business_id", "name", "state_", "city", "stars", "review_count", "customer_stars", "date_"]]
reduced_postohio
# Out:
#                   business_id              name state_         city  stars  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# ...                       ...               ...    ...          ...    ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
#
#        review_count  customer_stars             date_
# ...

# %%
#getting rid of null values
red_postohio = reduced_postohio[reduced_postohio["business_id"] != "#NAME?"]
red_postohio
# Out:
#                   business_id              name state_         city  stars  \
# 0      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 1      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 2      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 3      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# 4      JqSL9fNnkwsxQkqGJyHJ2g  101 Beer Kitchen     OH  Westerville    4.5
# ...                       ...               ...    ...          ...    ...
# 19928  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19929  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19930  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19931  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
# 19932  wdkK-cgkYHvS8tp12uwjBQ      Zuko's Pizza     OH     Hilliard    4.0
#
#        review_count  customer_stars             date_
# ...

# %%
#reading csv
precovid_texas = "precovid_texas2019.csv"
precovid_texas_df = pd.read_csv(precovid_texas)
precovid_texas_df
# Out:
#                   business_id                name state_      city  stars  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin    3.5
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# ...                       ...                 ...    ...       ...    ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
#
#        review_count  is_open  \
# 0                 9        1
# ...

# %%
#getting columns needed for dataframe
reduced_precovid_texas =precovid_texas_df[["business_id", "name", "state_", "city", "stars", "review_count", "customer_stars", "date_"]]
reduced_precovid_texas
# Out:
#                   business_id                name state_      city  stars  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin    3.5
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# ...                       ...                 ...    ...       ...    ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
#
#        review_count  customer_stars             date_
# ...

# %%
#getting rid of null values
red_precovid_texas = reduced_precovid_texas[reduced_precovid_texas["business_id"] != "#NAME?"]
red_precovid_texas
# Out:
#                   business_id                name state_      city  stars  \
# 0      FwO183blfDg8g6sFv-NTsQ    15th Street Cafe     TX    Austin    3.5
# 1      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 2      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 3      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# 4      Rba9Ol4jnTiov6_iAuoF5g   1618 Asian Fusion     TX    Austin    5.0
# ...                       ...                 ...    ...       ...    ...
# 17079  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17080  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17081  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17082  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
# 17083  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +Â Salad     TX  Bee Cave    4.5
#
#        review_count  customer_stars             date_
# ...

# %%
#reading csv
postcovid_texas = "postcovid_texas2020.csv"
postcovid_texas_df = pd.read_csv(postcovid_texas,encoding='latin-1')
postcovid_texas_df
# Out:
#                   business_id                name state_      city  stars  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# ...                       ...                 ...    ...       ...    ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
#
#        review_count  is_open  \
# 0               256        1
# ...

# %%
#getting columns needed for dataframe
reduced_posttexas =postcovid_texas_df[["business_id", "name", "state_", "city", "stars", "review_count", "customer_stars", "date_"]]
reduced_posttexas
# Out:
#                   business_id                name state_      city  stars  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# ...                       ...                 ...    ...       ...    ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
#
#        review_count  customer_stars            date_
# ...

# %%
#getting rid of null values
red_postcovid_texas = reduced_posttexas[reduced_posttexas["business_id"] != "#NAME?"]
red_postcovid_texas
# Out:
#                   business_id                name state_      city  stars  \
# 0      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 1      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 2      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 3      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# 4      6uSPLo9R0vxtJxPIhsMSMg      101 By Teahaus     TX    Austin    4.0
# ...                       ...                 ...    ...       ...    ...
# 46575  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46576  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46577  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46578  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
# 46579  sXgzgNe7YJO1A_86EKUyCw  ZZA Pizza +?ÿSalad     TX  Bee Cave    4.5
#
#        review_count  customer_stars            date_
# ...

# %%
rating_preohio3 = red_preohio[(red_preohio['stars']) == 3.0].nunique()
rating_preohio3
# Out:
# business_id        66
# name               55
# state_              1
# city               16
# stars               1
# review_count       51
# customer_stars      3
# date_             309
# dtype: int64

# %%
rating_red_postohio3 = red_postohio[(red_postohio['stars']) == 3.0].nunique()
rating_red_postohio3
# Out:
# business_id        330
# name               227
# state_               1
# city                29
# stars                1
# review_count       129
# customer_stars       3
# date_             1236
# dtype: int64

# %%
rating_preohio3half = red_preohio[(red_preohio['stars']) == 3.5].nunique()
rating_preohio3half
# Out:
# business_id        96
# name               93
# state_              1
# city               15
# stars               1
# review_count       78
# customer_stars      3
# date_             905
# dtype: int64

# %%
rating_red_postohio3half = red_postohio[(red_postohio['stars']) == 3.5].nunique()
rating_red_postohio3half
# Out:
# business_id        599
# name               471
# state_               1
# city                30
# stars                1
# review_count       201
# customer_stars       3
# date_             3318
# dtype: int64

# %%
rating_preohio4 = red_preohio[(red_preohio['stars']) == 4.0].nunique()
rating_preohio4
# Out:
# business_id        152
# name               147
# state_               1
# city                21
# stars                1
# review_count       107
# customer_stars       3
# date_             2409
# dtype: int64

# %%
rating_red_postohio4 = red_postohio[(red_postohio['stars']) == 4].nunique()
rating_red_postohio4
# Out:
# business_id        718
# name               628
# state_               1
# city                33
# stars                1
# review_count       290
# customer_stars       3
# date_             7571
# dtype: int64

# %%
rating_preohio4half = red_preohio[(red_preohio['stars']) == 4.5].nunique()
rating_preohio4half
# Out:
# business_id         70
# name                70
# state_               1
# city                15
# stars                1
# review_count        57
# customer_stars       3
# date_             1374
# dtype: int64

# %%
rating_postohio4half = red_postohio[(red_postohio['stars']) == 4.5].nunique()
rating_postohio4half
# Out:
# business_id        437
# name               416
# state_               1
# city                36
# stars                1
# review_count       202
# customer_stars       3
# date_             6003
# dtype: int64

# %%
rating_preohio5 = red_preohio[(red_preohio['stars']) == 5.0].nunique()
rating_preohio5
# Out:
# business_id        8
# name               8
# state_             1
# city               6
# stars              1
# review_count       7
# customer_stars     2
# date_             66
# dtype: int64

# %%
rating_postohio5 = red_postohio[(red_postohio['stars']) == 5.0].nunique()
rating_postohio5
# Out:
# business_id        68
# name               68
# state_              1
# city               16
# stars               1
# review_count       36
# customer_stars      3
# date_             632
# dtype: int64

# %%
X = [3, 3.5, 4, 4.5, 5]
Yprereviews = [51, 78, 107, 57, 7]
Zpostreviews = [129, 201, 290, 202, 36]

X_axis = np.arange(len(X))
   
plt.bar(X_axis - 0.2, Yprereviews, 0.4, label = 'Precovid Ohio 2019')
plt.bar(X_axis + 0.2, Zpostreviews, 0.4, label = 'Postcovid Ohio 2020')

plt.xticks(X_axis, X)
plt.xlabel("Review Ratings")
plt.ylabel("Number of Reviews")
plt.title("Precovid Ohio 2019 vs Postcovid Ohio 2020")
plt.savefig("PrecovidOhio2019_vs_PostcovidOhio2020.png")
plt.legend()
plt.show()

# %%
rating_pretexas3 = red_precovid_texas[(red_precovid_texas['stars']) == 3.0].nunique()
rating_pretexas3
# Out:
# business_id        45
# name               42
# state_              1
# city                5
# stars               1
# review_count       41
# customer_stars      3
# date_             384
# dtype: int64

# %%
rating_posttexas3 = red_postcovid_texas[(red_postcovid_texas['stars']) == 3.0].nunique()
rating_posttexas3
# Out:
# business_id        313
# name               236
# state_               1
# city                11
# stars                1
# review_count       186
# customer_stars       3
# date_             1753
# dtype: int64

# %%
rating_pretexas3half = red_precovid_texas[(red_precovid_texas['stars']) == 3.5].nunique()
rating_pretexas3half
# Out:
# business_id        124
# name               120
# state_               1
# city                 7
# stars                1
# review_count       108
# customer_stars       3
# date_             1913
# dtype: int64

# %%
rating_posttexas3half = red_postcovid_texas[(red_postcovid_texas['stars']) == 3.5].nunique()
rating_posttexas3half
# Out:
# business_id        623
# name               541
# state_               1
# city                12
# stars                1
# review_count       381
# customer_stars       3
# date_             6678
# dtype: int64

# %%
rating_pretexas4 = red_precovid_texas[(red_precovid_texas['stars']) == 4].nunique()
rating_pretexas4
# Out:
# business_id        132
# name               127
# state_               1
# city                 8
# stars                1
# review_count       118
# customer_stars       3
# date_             5502
# dtype: int64

# %%
rating_posttexas4 = red_postcovid_texas[(red_postcovid_texas['stars']) == 4].nunique()
rating_posttexas4
# Out:
# business_id         862
# name                757
# state_                1
# city                 13
# stars                 1
# review_count        477
# customer_stars        3
# date_             16089
# dtype: int64

# %%
rating_pretexas4half = red_precovid_texas[(red_precovid_texas['stars']) == 4.5].nunique()
rating_pretexas4half
# Out:
# business_id        124
# name               122
# state_               1
# city                10
# stars                1
# review_count       100
# customer_stars       3
# date_             7826
# dtype: int64

# %%
rating_posttexas4half = red_postcovid_texas[(red_postcovid_texas['stars']) == 4.5].nunique()
rating_posttexas4half
# Out:
# business_id         652
# name                620
# state_                1
# city                 17
# stars                 1
# review_count        320
# customer_stars        3
# date_             16320
# dtype: int64

# %%
rating_pretexas5 = red_precovid_texas[(red_precovid_texas['stars']) == 5].nunique()
rating_pretexas5
# Out:
# business_id        25
# name               25
# state_              1
# city                2
# stars               1
# review_count       23
# customer_stars      3
# date_             648
# dtype: int64

# %%
rating_posttexas5 = red_postcovid_texas[(red_postcovid_texas['stars']) == 5].nunique()
rating_posttexas5
# Out:
# business_id        178
# name               177
# state_               1
# city                 8
# stars                1
# review_count        81
# customer_stars       3
# date_             3066
# dtype: int64

# %%
X = [3, 3.5, 4, 4.5, 5]
Yprereviews = [41, 108, 118, 100, 23]
Zpostreviews = [186, 381, 477, 320, 81]

X_axis = np.arange(len(X))
   
plt.bar(X_axis - 0.2, Yprereviews, 0.4, label = 'Precovid Texas 2019')
plt.bar(X_axis + 0.2, Zpostreviews, 0.4, label = 'Postcovid Texas 2020')

plt.xticks(X_axis, X)
plt.xlabel("Review Ratings")
plt.ylabel("Number of Reviews")
plt.title("Precovid Texas 2019 vs Postcovid Texas 2020")
plt.savefig("PrecovidTexas2019_vs_PostcovidTexas2020.png")
plt.legend()
plt.show()

# %%
X = [3, 3.5, 4, 4.5, 5]
Yprereviews = [51, 78, 107, 57, 7]
Zpostreviews = [41, 108, 118, 100, 23]

X_axis = np.arange(len(X))
   
plt.bar(X_axis - 0.2, Yprereviews, 0.4, label = 'Precovid Ohio 2019')
plt.bar(X_axis + 0.2, Zpostreviews, 0.4, label = 'Precovid Texas 2019')

plt.xticks(X_axis, X)
plt.xlabel("Review Ratings")
plt.ylabel("Number of Reviews")
plt.title("Precovid Ohio 2019 vs Precovid Texas 2019")
plt.savefig("PrecovidOhio2019_vs_PrecovidTexas2019.png")
plt.legend()
plt.show()

# %%
X = [3, 3.5, 4, 4.5, 5]
Yprereviews = [129, 201, 290, 202, 36]
Zpostreviews = [186, 381, 477, 320, 81]

X_axis = np.arange(len(X))
   
plt.bar(X_axis - 0.2, Yprereviews, 0.4, label = 'Postcovid Ohio 2020')
plt.bar(X_axis + 0.2, Zpostreviews, 0.4, label = 'Postcovid Texas 2020')

plt.xticks(X_axis, X)
plt.xlabel("Review Ratings")
plt.ylabel("Number of Reviews")
plt.title("Postcovid Ohio 2020 vs Postcovid Texas 2020")
plt.savefig("PostcovidOhio2020_vs_PostcovidTexas2020.png")
plt.legend()
plt.show()
